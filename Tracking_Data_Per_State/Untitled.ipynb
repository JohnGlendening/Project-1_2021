# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import sem
import random
from scipy.stats import linregress
from sklearn import datasets
import scipy.stats as sts
import requests
import time
from scipy.stats import linregress

# %%
# File to Load (Remember to Change These)
file= "kansas-history.csv"

# Read Purchasing File and store into Pandas data frame
df= pd.read_csv(file)

# %%
df.head(20)
# Out:
#          date state   death  deathConfirmed  deathIncrease  deathProbable  \
# 0   2/25/2021    KS  4724.0             NaN              0            NaN
# 1   2/24/2021    KS  4724.0             NaN             81            NaN
# 2   2/23/2021    KS  4643.0             NaN              0            NaN
# 3   2/22/2021    KS  4643.0             NaN             29            NaN
# 4   2/21/2021    KS  4614.0             NaN              0            NaN
# 5   2/20/2021    KS  4614.0             NaN              0            NaN
# 6   2/19/2021    KS  4614.0             NaN             93            NaN
# 7   2/18/2021    KS  4521.0             NaN              0            NaN
# 8   2/17/2021    KS  4521.0             NaN            115            NaN
# 9   2/16/2021    KS  4406.0             NaN              0            NaN
# 10  2/15/2021    KS  4406.0             NaN             42            NaN
# 11  2/14/2021    KS  4364.0             NaN              0            NaN
# 12  2/13/2021    KS  4364.0             NaN              0            NaN
# 13  2/12/2021    KS  4364.0             NaN             61            NaN
# 14  2/11/2021    KS  4303.0             NaN              0            NaN
# 15  2/10/2021    KS  4303.0             NaN            106            NaN
# 16   2/9/2021    KS  4197.0             NaN              0            NaN
# 17   2/8/2021    KS  4197.0             NaN             96            NaN
# 18   2/7/2021    KS  4101.0             NaN              0            NaN
# 19   2/6/2021    KS  4101.0             NaN              0            NaN
#
#     hospitalized  hospitalizedCumulative  hospitalizedCurrently  \
# 0         9189.0                  9189.0                  214.0
# 1         9189.0                  9189.0                  214.0
# 2         9103.0                  9103.0                  214.0
# 3         9103.0                  9103.0                  214.0
# 4         9071.0                  9071.0                  290.0
# 5         9071.0                  9071.0                  290.0
# 6         9071.0                  9071.0                  290.0
# 7         9002.0                  9002.0                  300.0
# 8         9002.0                  9002.0                  300.0
# 9         8923.0                  8923.0                  279.0
# 10        8923.0                  8923.0                  279.0
# 11        8887.0                  8887.0                  348.0
# 12        8887.0                  8887.0                  348.0
# 13        8887.0                  8887.0                  348.0
# 14        8840.0                  8840.0                  377.0
# 15        8840.0                  8840.0                  377.0
# 16        8749.0                  8749.0                  319.0
# 17        8749.0                  8749.0                  319.0
# 18        8680.0                  8680.0                  526.0
# 19        8680.0                  8680.0                  526.0
#
#     hospitalizedIncrease  ...  totalTestResults  totalTestResultsIncrease  \
# 0                      0  ...           1248768                         0
# 1                     86  ...           1248768                      5269
# 2                      0  ...           1243499                         0
# 3                     32  ...           1243499                      5076
# 4                      0  ...           1238423                         0
# 5                      0  ...           1238423                         0
# 6                     69  ...           1238423                      9125
# 7                      0  ...           1229298                         0
# 8                     79  ...           1229298                      5066
# 9                      0  ...           1224232                         0
# 10                    36  ...           1224232                      6643
# 11                     0  ...           1217589                         0
# 12                     0  ...           1217589                         0
# 13                    47  ...           1217589                      6096
# 14                     0  ...           1211493                         0
# 15                    91  ...           1211493                      7734
# 16                     0  ...           1203759                         0
# 17                    69  ...           1203759                      6706
# 18                     0  ...           1197053                         0
# 19                     0  ...           1197053                         0
#
#     totalTestsAntibody  totalTestsAntigen  totalTestsPeopleAntibody  \
# 0                  NaN           573408.0                       NaN
# 1                  NaN           573408.0                       NaN
# 2                  NaN           563612.0                       NaN
# 3                  NaN           563612.0                       NaN
# 4                  NaN           558292.0                       NaN
# 5                  NaN           558292.0                       NaN
# 6                  NaN           558292.0                       NaN
# 7                  NaN           543223.0                       NaN
# 8                  NaN           543223.0                       NaN
# 9                  NaN           534602.0                       NaN
# 10                 NaN           534602.0                       NaN
# 11                 NaN           527485.0                       NaN
# 12                 NaN           527485.0                       NaN
# 13                 NaN           527485.0                       NaN
# 14                 NaN                NaN                       NaN
# 15                 NaN                NaN                       NaN
# 16                 NaN                NaN                       NaN
# 17                 NaN                NaN                       NaN
# 18                 NaN                NaN                       NaN
# 19                 NaN                NaN                       NaN
#
#     totalTestsPeopleAntigen  totalTestsPeopleViral  \
# 0                       NaN              1248768.0
# 1                       NaN              1248768.0
# 2                       NaN              1243499.0
# 3                       NaN              1243499.0
# 4                       NaN              1238423.0
# 5                       NaN              1238423.0
# 6                       NaN              1238423.0
# 7                       NaN              1229298.0
# 8                       NaN              1229298.0
# 9                       NaN              1224232.0
# 10                      NaN              1224232.0
# 11                      NaN              1217589.0
# 12                      NaN              1217589.0
# 13                      NaN              1217589.0
# 14                      NaN              1211493.0
# 15                      NaN              1211493.0
# 16                      NaN              1203759.0
# 17                      NaN              1203759.0
# 18                      NaN              1197053.0
# 19                      NaN              1197053.0
#
#     totalTestsPeopleViralIncrease  totalTestsViral  totalTestsViralIncrease
# 0                               0        2438740.0                        0
# 1                            5269        2438740.0                    19844
# 2                               0        2418896.0                        0
# 3                            5076        2418896.0                    15821
# 4                               0        2403075.0                        0
# 5                               0        2403075.0                        0
# 6                            9125        2403075.0                    20552
# 7                               0        2382523.0                        0
# 8                            5066        2382523.0                    17858
# 9                               0        2364665.0                        0
# 10                           6643        2364665.0                    18212
# 11                              0        2346453.0                        0
# 12                              0        2346453.0                        0
# 13                           6096        2346453.0                    21097
# 14                              0        2325356.0                        0
# 15                           7734        2325356.0                    23909
# 16                              0        2301447.0                        0
# 17                           6706        2301447.0                    18488
# 18                              0        2282959.0                        0
# 19                              0        2282959.0                        0
#
# [20 rows x 41 columns]

# %%
df.count()
# Out:
# date                                357
# state                               357
# death                               349
# deathConfirmed                        0
# deathIncrease                       357
# deathProbable                         0
# hospitalized                        336
# hospitalizedCumulative              336
# hospitalizedCurrently               216
# hospitalizedIncrease                357
# inIcuCumulative                     303
# inIcuCurrently                      226
# negative                            357
# negativeIncrease                    357
# negativeTestsAntibody                 0
# negativeTestsPeopleAntibody           0
# negativeTestsViral                    0
# onVentilatorCumulative              303
# onVentilatorCurrently               226
# positive                            357
# positiveCasesViral                    0
# positiveIncrease                    357
# positiveScore                       357
# positiveTestsAntibody                 0
# positiveTestsAntigen                  0
# positiveTestsPeopleAntibody           0
# positiveTestsPeopleAntigen            0
# positiveTestsViral                    0
# recovered                             0
# totalTestEncountersViral              0
# totalTestEncountersViralIncrease    357
# totalTestResults                    357
# totalTestResultsIncrease            357
# totalTestsAntibody                    0
# totalTestsAntigen                    14
# totalTestsPeopleAntibody              0
# totalTestsPeopleAntigen               0
# totalTestsPeopleViral               277
# totalTestsPeopleViralIncrease       357
# totalTestsViral                      30
# totalTestsViralIncrease             357
# dtype: int64
