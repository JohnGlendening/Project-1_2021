# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd

# %%
# File to Load (Remember to Change These)
file1="census_data.csv"

# Read Purchasing File and store into Pandas data frame

df= pd.read_csv(file1)

# %%
df
# Out:
#                                                 Label Alabama!!Estimate  \
# 0                                              Total:         4,903,185
# 1                             Population of one race:         4,811,663
# 2                                               White         3,326,375
# 3                           Black or African American         1,319,551
# 4                   American Indian and Alaska Native            23,265
# 5                                               Asian            66,129
# 6           Native Hawaiian and Other Pacific Isla...             1,892
# 7                                     Some other race            74,451
# 8                    Population of two or more races:            91,522
# 9                 Two races including Some other race             6,258
# 10          Two races excluding Some other race, a...            85,264
# 11                           Population of two races:            85,438
# ...
